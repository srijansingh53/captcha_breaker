# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
import os
os.chdir('/content/drive/My Drive/project_captcha/dataset/')
# !ls
# Out:
# captcha_labelled  deskewed   letters	     processed
# combined	  label.csv  lightning_logs

# %%
import cv2
import numpy as np
import pandas as pd

import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torchvision import transforms, datasets, models
from torch.autograd import Variable
from torch.utils.data import DataLoader, Dataset, sampler, random_split, SubsetRandomSampler, WeightedRandomSampler
from torchsummary import summary


import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
# Out:
# /usr/local/lib/python3.6/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %%
np.random.seed(0)
torch.manual_seed(0)

# %%
''' Declaring important parameters '''

data_dir = 'letters'
nThreads = 4
batch_size = 32

# %% [markdown]
# ## Loading/Splitting Dataset

# %%
''' Loading dataset and splitting it into train and test set '''
def load_split_train_test(datadir, valid_size = .2):

    train_transforms = transforms.Compose([transforms.Resize(100),
                                           transforms.ToTensor(),
                                           ])
    test_transforms = transforms.Compose([transforms.Resize(100),
                                          transforms.ToTensor(),
                                          ])
    train_data = datasets.ImageFolder(datadir, transform=train_transforms)
    test_data = datasets.ImageFolder(datadir, transform=test_transforms)
    num_train = len(train_data)
    indices = list(range(num_train))
    split = int(np.floor(valid_size * num_train))
    np.random.shuffle(indices)

    train_idx, test_idx = indices[split:], indices[:split]
    train_sampler = sampler.SubsetRandomSampler(train_idx)
    test_sampler = sampler.SubsetRandomSampler(test_idx)
    trainloader = DataLoader(train_data,
                   sampler=train_sampler, batch_size=64)
    testloader = DataLoader(test_data,
                   sampler=test_sampler, batch_size=64)
    return trainloader, testloader

trainloader, testloader = load_split_train_test(data_dir, .2)
print(testloader.dataset.classes)

# %% [markdown]
# Another method of splitting

# %%
image_transforms = {
    "train": transforms.Compose([
        transforms.Grayscale(),
        transforms.Resize((100, 100)),
        transforms.ToTensor()
    ])
}

# %%
letters_dataset = datasets.ImageFolder(
                              root = data_dir,
                              transform = image_transforms["train"]
                       )

# %%
letters_dataset
# Out:
# Dataset ImageFolder
#     Number of datapoints: 10355
#     Root location: letters
#     StandardTransform
# Transform: Compose(
#                Grayscale(num_output_channels=1)
#                Resize(size=(100, 100), interpolation=PIL.Image.BILINEAR)
#                ToTensor()
#            )

# %%
print(letters_dataset.classes)
print(letters_dataset.class_to_idx)
# Out:
# ['2', '3', '4', '5', '6', '7', '8', '9', 'A', 'C', 'D', 'E', 'F', 'G', 'H', 'J', 'K', 'M', 'N', 'P', 'Q', 'R', 'S', 'T', 'U', 'V', 'W', 'X', 'Y', 'Z']
# {'2': 0, '3': 1, '4': 2, '5': 3, '6': 4, '7': 5, '8': 6, '9': 7, 'A': 8, 'C': 9, 'D': 10, 'E': 11, 'F': 12, 'G': 13, 'H': 14, 'J': 15, 'K': 16, 'M': 17, 'N': 18, 'P': 19, 'Q': 20, 'R': 21, 'S': 22, 'T': 23, 'U': 24, 'V': 25, 'W': 26, 'X': 27, 'Y': 28, 'Z': 29}

# %%
idx2class = {v: k for k, v in letters_dataset.class_to_idx.items()}
print(idx2class)
# Out:
# {0: '2', 1: '3', 2: '4', 3: '5', 4: '6', 5: '7', 6: '8', 7: '9', 8: 'A', 9: 'C', 10: 'D', 11: 'E', 12: 'F', 13: 'G', 14: 'H', 15: 'J', 16: 'K', 17: 'M', 18: 'N', 19: 'P', 20: 'Q', 21: 'R', 22: 'S', 23: 'T', 24: 'U', 25: 'V', 26: 'W', 27: 'X', 28: 'Y', 29: 'Z'}

# %%
def get_class_distribution(dataset_obj):
    count_dict = {k:0 for k,v in dataset_obj.class_to_idx.items()}
    
    for element in dataset_obj:
        y_lbl = element[1]
        y_lbl = idx2class[y_lbl]
        count_dict[y_lbl] += 1
            
    return count_dict
# print("Distribution of classes: \n", get_class_distribution(letters_dataset))

# %%
plt.figure(figsize=(15,8))
sns.barplot(data = pd.DataFrame.from_dict([get_class_distribution(letters_dataset)]).melt(),
            x = "variable", y="value", hue="variable").set_title('Letters Class Distribution')

# %% [markdown]
# Random split

# %%
train_dataset, val_dataset = random_split(letters_dataset, (8000, 2355))

train_loader = DataLoader(dataset=train_dataset, shuffle=True, batch_size=32)
val_loader = DataLoader(dataset=val_dataset, shuffle=False, batch_size=32)
print("Length of the train_loader:", len(train_loader))
print("Length of the val_loader:", len(val_loader))
# Out:
# Length of the train_loader: 250
# Length of the val_loader: 74

# %%
''' Vizualize Images from dataloader '''

dataiter = iter(train_loader)
images, labels = dataiter.next()
print(type(images))
print(images.shape)
print(labels.shape)
image = np.transpose(images[0].numpy(), (1, 2, 0))
image = image.reshape(100,100)
print(set(image.flatten()))
plt.imshow(image, cmap='gray')
# Out:
# <class 'torch.Tensor'>
# torch.Size([32, 1, 100, 100])
# torch.Size([32])
# {0.0, 0.007843138, 0.99215686, 0.003921569, 0.011764706, 1.0, 0.99607843, 0.98039216, 0.9882353, 0.9843137, 0.019607844, 0.015686275, 0.972549, 0.9764706, 0.02745098, 0.023529412}

# %% [markdown]
# Model

# %%
device = torch.device("cuda" if torch.cuda.is_available() 
                                  else "cpu")
print(device)
# Out:
# cuda

# %% [markdown]
# ##Training

# %%
class CustomNet(nn.Module):
    def __init__(self):
        super(CustomNet, self).__init__()
        self.cnn_model = nn.Sequential(
            nn.Conv2d(1, 4, kernel_size = 5),
            nn.ReLU(),
            nn.AvgPool2d(2, stride = 2),
            nn.Conv2d(4, 8, kernel_size = 3),
            nn.ReLU(),
            nn.AvgPool2d(2, stride = 2),
            nn.Conv2d(8,16,kernel_size = 3),
            nn.ReLU(),
            nn.AvgPool2d(2, stride = 2),
            nn.Conv2d(16,32,kernel_size = 3),
            nn.ReLU(),
            nn.AvgPool2d(2, stride = 2))

        self.fc_model = nn.Sequential(
            nn.Linear(512, 256), # (N, 2592) -> (N, 512)
            nn.ReLU(),
            nn.Linear(256, 30))  # (N, 512)  -> (N, 30)) #30 classes

    def forward(self, x):
        # print(x.shape)
        x = self.cnn_model(x)
        # print(x.shape) 
        x = x.view(x.size(0), -1)
        # print(x.shape)    
        x = self.fc_model(x)
        # print(x.shape)
        return x

# %%
model = CustomNet().to(device)
loss_fn = nn.CrossEntropyLoss()
opt = optim.Adam(model.parameters(), lr=0.001)

# %%
summary(model, (1, 100, 100))
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1            [-1, 4, 96, 96]             104
#               ReLU-2            [-1, 4, 96, 96]               0
#          AvgPool2d-3            [-1, 4, 48, 48]               0
#             Conv2d-4            [-1, 8, 46, 46]             296
#               ReLU-5            [-1, 8, 46, 46]               0
#          AvgPool2d-6            [-1, 8, 23, 23]               0
#             Conv2d-7           [-1, 16, 21, 21]           1,168
#               ReLU-8           [-1, 16, 21, 21]               0
#          AvgPool2d-9           [-1, 16, 10, 10]               0
#            Conv2d-10             [-1, 32, 8, 8]           4,640
#              ReLU-11             [-1, 32, 8, 8]               0
#         AvgPool2d-12             [-1, 32, 4, 4]               0
#            Linear-13                  [-1, 256]         131,328
#              ReLU-14                  [-1, 256]               0
#            Linear-15                   [-1, 30]           7,710
# ================================================================
# Total params: 145,246
# Trainable params: 145,246
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.04
# Forward/backward pass size (MB): 1.08
# Params size (MB): 0.55
# Estimated Total Size (MB): 1.67
# ----------------------------------------------------------------

# %%
# Find total parameters and trainable parameters
total_params = sum(p.numel() for p in model.parameters())
print(f'{total_params:,} total parameters.')
total_trainable_params = sum(p.numel() for p in model.parameters() if p.requires_grad)
print(f'{total_trainable_params:,} training parameters.')
# Out:
# 145,246 total parameters.
# 145,246 training parameters.

# %%
def evaluation(dataloader):
    total, correct = 0, 0
    #keeping the network in evaluation mode 
    model.eval()
    for data in dataloader:
        inputs, labels = data
        #moving the inputs and labels to gpu
        inputs, labels = inputs.to(device), labels.to(device)
        outputs = model(inputs)
        _, pred = torch.max(outputs.data, 1)
        total += labels.size(0)
        correct += (pred == labels).sum().item()
    return 100 * correct / total

# %%
iter = []
loss_arr = []
loss_epoch_arr = []
max_epochs = 10 #epoch count
val_max_acc = 0.0
for epoch in range(max_epochs):

    for i, data in enumerate(train_loader, 0):

        inputs, labels = data
        # print(labels)
        inputs, labels = inputs.to(device), labels.to(device)
        # print()
        #forward pass
        outputs = model(inputs)
        # print('a')
        loss = loss_fn(outputs, labels)
        
        #backward and optimize
        opt.zero_grad()
        loss.backward()
        opt.step()

        if (i+1)%50 ==0:
            iter.append(i)
            loss_arr.append(loss.item())
            val_acc = evaluation(val_loader)
            train_acc = evaluation(train_loader)
            print('Epoch: %d/%d, Iterations: %d/%d, Loss: %0.4f, Test acc: %0.2f, Train acc: %0.2f' % (epoch+1, max_epochs, i+1, len(train_loader), loss.data, val_acc, train_acc))
            if val_acc>val_max_acc:
                print('Validation accuracy improved from %0.4f to %0.4f. Saving best model.....' % (val_max_acc,val_acc))
                val_max_acc = val_acc
                full_model_path = '../models/pytorch/lenet10_full.pth'
                torch.save(model, full_model_path)
            else:
                print('Validation accuracy did not improved from %0.4f. Continuing training.....' % (val_max_acc))
    loss_epoch_arr.append(loss.item())
        
    # print('Epoch: %d/%d, Test acc: %0.2f, Train acc: %0.2f' % (epoch, max_epochs, evaluation(val_loader), evaluation(train_loader)))
# Out:
# Epoch: 1/10, Iterations: 50/250, Loss: 3.1649, Test acc: 9.17, Train acc: 8.66
# Validation accuracy improved from 0.0000 to 9.1720. Saving best model.....
# Epoch: 1/10, Iterations: 100/250, Loss: 1.6969, Test acc: 40.59, Train acc: 41.46
# Validation accuracy improved from 9.1720 to 40.5945. Saving best model.....
# Epoch: 1/10, Iterations: 150/250, Loss: 0.8952, Test acc: 74.31, Train acc: 75.66
# Validation accuracy improved from 40.5945 to 74.3100. Saving best model.....
# Epoch: 1/10, Iterations: 200/250, Loss: 0.6557, Test acc: 85.65, Train acc: 86.29
# Validation accuracy improved from 74.3100 to 85.6476. Saving best model.....
# Epoch: 1/10, Iterations: 250/250, Loss: 0.7840, Test acc: 86.67, Train acc: 88.17
# Validation accuracy improved from 85.6476 to 86.6667. Saving best model.....
# Epoch: 2/10, Iterations: 50/250, Loss: 0.2745, Test acc: 91.21, Train acc: 92.19
# Validation accuracy improved from 86.6667 to 91.2102. Saving best model.....
# Epoch: 2/10, Iterations: 100/250, Loss: 0.1093, Test acc: 93.08, Train acc: 93.25
# Validation accuracy improved from 91.2102 to 93.0786. Saving best model.....
# Epoch: 2/10, Iterations: 150/250, Loss: 0.3737, Test acc: 94.69, Train acc: 95.08
# Validation accuracy improved from 93.0786 to 94.6921. Saving best model.....
# Epoch: 2/10, Iterations: 200/250, Loss: 0.3634, Test acc: 94.52, Train acc: 95.70
# Validation accuracy did not improved from 94.6921. Continuing training.....
# Epoch: 2/10, Iterations: 250/250, Loss: 0.3960, Test acc: 94.39, Train acc: 94.62
# Validation accuracy did not improved from 94.6921. Continuing training.....
# Epoch: 3/10, Iterations: 50/250, Loss: 0.4620, Test acc: 95.75, Train acc: 96.56
# Validation accuracy improved from 94.6921 to 95.7537. Saving best model.....
# Epoch: 3/10, Iterations: 100/250, Loss: 0.1607, Test acc: 96.48, Train acc: 96.85
# Validation accuracy improved from 95.7537 to 96.4756. Saving best model.....
# Epoch: 3/10, Iterations: 150/250, Loss: 0.2511, Test acc: 94.95, Train acc: 96.40
# Validation accuracy did not improved from 96.4756. Continuing training.....
# Epoch: 3/10, Iterations: 200/250, Loss: 0.0338, Test acc: 95.58, Train acc: 95.80
# Validation accuracy did not improved from 96.4756. Continuing training.....
# Epoch: 3/10, Iterations: 250/250, Loss: 0.0618, Test acc: 96.31, Train acc: 97.67
# Validation accuracy did not improved from 96.4756. Continuing training.....
# Epoch: 4/10, Iterations: 50/250, Loss: 0.2406, Test acc: 96.69, Train acc: 97.94
# Validation accuracy improved from 96.4756 to 96.6879. Saving best model.....
# Epoch: 4/10, Iterations: 100/250, Loss: 0.0177, Test acc: 95.92, Train acc: 96.79
# Validation accuracy did not improved from 96.6879. Continuing training.....
# Epoch: 4/10, Iterations: 150/250, Loss: 0.0086, Test acc: 96.43, Train acc: 96.95
# Validation accuracy did not improved from 96.6879. Continuing training.....
# Epoch: 4/10, Iterations: 200/250, Loss: 0.3424, Test acc: 96.56, Train acc: 97.85
# Validation accuracy did not improved from 96.6879. Continuing training.....
# Epoch: 4/10, Iterations: 250/250, Loss: 0.1317, Test acc: 96.48, Train acc: 97.06
# Validation accuracy did not improved from 96.6879. Continuing training.....
# Epoch: 5/10, Iterations: 50/250, Loss: 0.0264, Test acc: 95.54, Train acc: 96.62
# Validation accuracy did not improved from 96.6879. Continuing training.....
# Epoch: 5/10, Iterations: 100/250, Loss: 0.0300, Test acc: 95.50, Train acc: 96.79
# Validation accuracy did not improved from 96.6879. Continuing training.....
# Epoch: 5/10, Iterations: 150/250, Loss: 0.1266, Test acc: 96.77, Train acc: 98.54
# Validation accuracy improved from 96.6879 to 96.7728. Saving best model.....
# Epoch: 5/10, Iterations: 200/250, Loss: 0.0335, Test acc: 96.77, Train acc: 98.28
# Validation accuracy did not improved from 96.7728. Continuing training.....
# Epoch: 5/10, Iterations: 250/250, Loss: 0.1194, Test acc: 95.80, Train acc: 97.03
# Validation accuracy did not improved from 96.7728. Continuing training.....
# Epoch: 6/10, Iterations: 50/250, Loss: 0.0025, Test acc: 97.88, Train acc: 99.04
# Validation accuracy improved from 96.7728 to 97.8769. Saving best model.....
# Epoch: 6/10, Iterations: 100/250, Loss: 0.0057, Test acc: 97.49, Train acc: 98.99
# Validation accuracy did not improved from 97.8769. Continuing training.....
# Epoch: 6/10, Iterations: 150/250, Loss: 0.0555, Test acc: 97.54, Train acc: 98.81
# Validation accuracy did not improved from 97.8769. Continuing training.....
# Epoch: 6/10, Iterations: 200/250, Loss: 0.0095, Test acc: 97.79, Train acc: 99.40
# Validation accuracy did not improved from 97.8769. Continuing training.....
# Epoch: 6/10, Iterations: 250/250, Loss: 0.0246, Test acc: 97.54, Train acc: 98.51
# Validation accuracy did not improved from 97.8769. Continuing training.....
# Epoch: 7/10, Iterations: 50/250, Loss: 0.0526, Test acc: 97.62, Train acc: 99.30
# Validation accuracy did not improved from 97.8769. Continuing training.....
# Epoch: 7/10, Iterations: 100/250, Loss: 0.0006, Test acc: 97.83, Train acc: 99.12
# Validation accuracy did not improved from 97.8769. Continuing training.....
# Epoch: 7/10, Iterations: 150/250, Loss: 0.0586, Test acc: 96.69, Train acc: 98.15
# Validation accuracy did not improved from 97.8769. Continuing training.....
# Epoch: 7/10, Iterations: 200/250, Loss: 0.0008, Test acc: 97.96, Train acc: 99.47
# Validation accuracy improved from 97.8769 to 97.9618. Saving best model.....
# Epoch: 7/10, Iterations: 250/250, Loss: 0.0075, Test acc: 97.45, Train acc: 98.81
# Validation accuracy did not improved from 97.9618. Continuing training.....
# Epoch: 8/10, Iterations: 50/250, Loss: 0.0364, Test acc: 97.66, Train acc: 99.44
# Validation accuracy did not improved from 97.9618. Continuing training.....
# Epoch: 8/10, Iterations: 100/250, Loss: 0.0095, Test acc: 98.17, Train acc: 99.62
# Validation accuracy improved from 97.9618 to 98.1741. Saving best model.....
# Epoch: 8/10, Iterations: 150/250, Loss: 0.0187, Test acc: 96.99, Train acc: 99.08
# Validation accuracy did not improved from 98.1741. Continuing training.....
# Epoch: 8/10, Iterations: 200/250, Loss: 0.0055, Test acc: 97.66, Train acc: 99.41
# Validation accuracy did not improved from 98.1741. Continuing training.....
# Epoch: 8/10, Iterations: 250/250, Loss: 0.0567, Test acc: 97.45, Train acc: 99.08
# Validation accuracy did not improved from 98.1741. Continuing training.....
# Epoch: 9/10, Iterations: 50/250, Loss: 0.0236, Test acc: 97.28, Train acc: 99.15
# Validation accuracy did not improved from 98.1741. Continuing training.....
# Epoch: 9/10, Iterations: 100/250, Loss: 0.0031, Test acc: 97.62, Train acc: 99.33
# Validation accuracy did not improved from 98.1741. Continuing training.....
# Epoch: 9/10, Iterations: 150/250, Loss: 0.0028, Test acc: 97.75, Train acc: 99.42
# Validation accuracy did not improved from 98.1741. Continuing training.....
# Epoch: 9/10, Iterations: 200/250, Loss: 0.0227, Test acc: 97.62, Train acc: 99.30
# Validation accuracy did not improved from 98.1741. Continuing training.....
# Epoch: 9/10, Iterations: 250/250, Loss: 0.0420, Test acc: 97.79, Train acc: 99.56
# Validation accuracy did not improved from 98.1741. Continuing training.....
# Epoch: 10/10, Iterations: 50/250, Loss: 0.0217, Test acc: 97.83, Train acc: 99.26
# Validation accuracy did not improved from 98.1741. Continuing training.....
# Epoch: 10/10, Iterations: 100/250, Loss: 0.0042, Test acc: 97.62, Train acc: 99.59
# Validation accuracy did not improved from 98.1741. Continuing training.....
# Epoch: 10/10, Iterations: 150/250, Loss: 0.0049, Test acc: 97.92, Train acc: 99.69
# Validation accuracy did not improved from 98.1741. Continuing training.....
# Epoch: 10/10, Iterations: 200/250, Loss: 0.0001, Test acc: 98.22, Train acc: 99.79
# Validation accuracy improved from 98.1741 to 98.2166. Saving best model.....
# Epoch: 10/10, Iterations: 250/250, Loss: 0.0374, Test acc: 96.77, Train acc: 98.60
# Validation accuracy did not improved from 98.2166. Continuing training.....

# %%
plt.plot(loss_epoch_arr)
plt.show()

# %%
plt.plot(loss_arr)
plt.show()

# %%
model_path = '../models/pytorch/lenet9.pth'
torch.save(model.state_dict(), model_path)

# %%
full_model_path = '../models/pytorch/lenet9_full.pth'
torch.save(model, full_model_path)

# %% [markdown]
# ## Inference

# %%
from PIL import Image
img = Image.open('letters/A/7531.jpg')
# img = cv2.imread('letters/2/24.jpg',-1)
plt.imshow(img,cmap='gray')

# %%
img_t = image_transforms["train"](img)
batch_t = torch.unsqueeze(img_t, 0)

# %%
full_model_path = '../models/pytorch/lenet5_full.pth'
model = torch.load(full_model_path)
model.eval()
# Out:
# CustomNet(
#   (cnn_model): Sequential(
#     (0): Conv2d(1, 4, kernel_size=(5, 5), stride=(1, 1))
#     (1): ReLU()
#     (2): AvgPool2d(kernel_size=2, stride=2, padding=0)
#     (3): Conv2d(4, 8, kernel_size=(3, 3), stride=(1, 1))
#     (4): ReLU()
#     (5): AvgPool2d(kernel_size=2, stride=2, padding=0)
#     (6): Conv2d(8, 16, kernel_size=(3, 3), stride=(1, 1))
#     (7): ReLU()
#     (8): AvgPool2d(kernel_size=2, stride=2, padding=0)
#     (9): Conv2d(16, 32, kernel_size=(3, 3), stride=(1, 1))
#     (10): ReLU()
#     (11): AvgPool2d(kernel_size=2, stride=2, padding=0)
#   )
#   (fc_model): Sequential(
#     (0): Linear(in_features=512, out_features=256, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=256, out_features=30, bias=True)
#   )
# )

# %%
out = model(batch_t.to(device))
print(out.shape)
# Out:
# torch.Size([1, 30])

# %%
prediction = int(torch.max(out.cpu().data, 1)[1].numpy())
print(prediction)
# Out:
# 8

# %%
letter = idx2class[prediction]
print(letter)
# Out:
# A
