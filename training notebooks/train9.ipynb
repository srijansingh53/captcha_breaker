# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
import os
os.chdir('/content/drive/My Drive/project_captcha/dataset/')
# !ls
# Out:
# captcha_labelled  deskewed   letters	     processed
# combined	  label.csv  lightning_logs

# %%
import cv2
import numpy as np
import pandas as pd

import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torchvision import transforms, datasets, models
from torch.autograd import Variable
from torch.utils.data import DataLoader, Dataset, sampler, random_split, SubsetRandomSampler, WeightedRandomSampler
from torchsummary import summary


import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
# Out:
# /usr/local/lib/python3.6/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %%
np.random.seed(0)
torch.manual_seed(0)

# %%
''' Declaring important parameters '''

data_dir = 'letters'
nThreads = 4
batch_size = 32

# %% [markdown]
# ## Loading/Splitting Dataset

# %%
''' Loading dataset and splitting it into train and test set '''
def load_split_train_test(datadir, valid_size = .2):

    train_transforms = transforms.Compose([transforms.Resize(100),
                                           transforms.ToTensor(),
                                           ])
    test_transforms = transforms.Compose([transforms.Resize(100),
                                          transforms.ToTensor(),
                                          ])
    train_data = datasets.ImageFolder(datadir, transform=train_transforms)
    test_data = datasets.ImageFolder(datadir, transform=test_transforms)
    num_train = len(train_data)
    indices = list(range(num_train))
    split = int(np.floor(valid_size * num_train))
    np.random.shuffle(indices)

    train_idx, test_idx = indices[split:], indices[:split]
    train_sampler = sampler.SubsetRandomSampler(train_idx)
    test_sampler = sampler.SubsetRandomSampler(test_idx)
    trainloader = DataLoader(train_data,
                   sampler=train_sampler, batch_size=64)
    testloader = DataLoader(test_data,
                   sampler=test_sampler, batch_size=64)
    return trainloader, testloader

trainloader, testloader = load_split_train_test(data_dir, .2)
print(testloader.dataset.classes)

# %% [markdown]
# Another method of splitting

# %%
image_transforms = {
    "train": transforms.Compose([
        transforms.Grayscale(),
        transforms.Resize((100, 100)),
        transforms.ToTensor()
    ])
}

# %%
letters_dataset = datasets.ImageFolder(
                              root = data_dir,
                              transform = image_transforms["train"]
                       )

# %%
letters_dataset
# Out:
# Dataset ImageFolder
#     Number of datapoints: 10355
#     Root location: letters
#     StandardTransform
# Transform: Compose(
#                Grayscale(num_output_channels=1)
#                Resize(size=(100, 100), interpolation=PIL.Image.BILINEAR)
#                ToTensor()
#            )

# %%
print(letters_dataset.classes)
print(letters_dataset.class_to_idx)
# Out:
# ['2', '3', '4', '5', '6', '7', '8', '9', 'A', 'C', 'D', 'E', 'F', 'G', 'H', 'J', 'K', 'M', 'N', 'P', 'Q', 'R', 'S', 'T', 'U', 'V', 'W', 'X', 'Y', 'Z']
# {'2': 0, '3': 1, '4': 2, '5': 3, '6': 4, '7': 5, '8': 6, '9': 7, 'A': 8, 'C': 9, 'D': 10, 'E': 11, 'F': 12, 'G': 13, 'H': 14, 'J': 15, 'K': 16, 'M': 17, 'N': 18, 'P': 19, 'Q': 20, 'R': 21, 'S': 22, 'T': 23, 'U': 24, 'V': 25, 'W': 26, 'X': 27, 'Y': 28, 'Z': 29}

# %%
idx2class = {v: k for k, v in letters_dataset.class_to_idx.items()}
print(idx2class)
# Out:
# {0: '2', 1: '3', 2: '4', 3: '5', 4: '6', 5: '7', 6: '8', 7: '9', 8: 'A', 9: 'C', 10: 'D', 11: 'E', 12: 'F', 13: 'G', 14: 'H', 15: 'J', 16: 'K', 17: 'M', 18: 'N', 19: 'P', 20: 'Q', 21: 'R', 22: 'S', 23: 'T', 24: 'U', 25: 'V', 26: 'W', 27: 'X', 28: 'Y', 29: 'Z'}

# %%
def get_class_distribution(dataset_obj):
    count_dict = {k:0 for k,v in dataset_obj.class_to_idx.items()}
    
    for element in dataset_obj:
        y_lbl = element[1]
        y_lbl = idx2class[y_lbl]
        count_dict[y_lbl] += 1
            
    return count_dict
# print("Distribution of classes: \n", get_class_distribution(letters_dataset))

# %%
plt.figure(figsize=(15,8))
sns.barplot(data = pd.DataFrame.from_dict([get_class_distribution(letters_dataset)]).melt(),
            x = "variable", y="value", hue="variable").set_title('Letters Class Distribution')

# %% [markdown]
# Random split

# %%
train_dataset, val_dataset = random_split(letters_dataset, (8000, 2355))

train_loader = DataLoader(dataset=train_dataset, shuffle=True, batch_size=32)
val_loader = DataLoader(dataset=val_dataset, shuffle=False, batch_size=32)
print("Length of the train_loader:", len(train_loader))
print("Length of the val_loader:", len(val_loader))
# Out:
# Length of the train_loader: 250
# Length of the val_loader: 74

# %%
''' Vizualize Images from dataloader '''

dataiter = iter(train_loader)
images, labels = dataiter.next()
print(type(images))
print(images.shape)
print(labels.shape)
image = np.transpose(images[0].numpy(), (1, 2, 0))
image = image.reshape(100,100)
print(set(image.flatten()))
plt.imshow(image, cmap='gray')
# Out:
# <class 'torch.Tensor'>
# torch.Size([32, 1, 100, 100])
# torch.Size([32])
# {0.0, 0.007843138, 0.99215686, 0.003921569, 0.011764706, 1.0, 0.99607843, 0.98039216, 0.9882353, 0.9843137, 0.019607844, 0.015686275, 0.972549, 0.9764706, 0.02745098, 0.023529412}

# %% [markdown]
# Model

# %%
device = torch.device("cuda" if torch.cuda.is_available() 
                                  else "cpu")
print(device)
# Out:
# cuda

# %% [markdown]
# ##Training

# %%
class CustomNet(nn.Module):
    def __init__(self):
        super(CustomNet, self).__init__()
        self.cnn_model = nn.Sequential(
            nn.Conv2d(1, 4, kernel_size = 3),
            nn.ReLU(),
            nn.AvgPool2d(2, stride = 2),
            nn.Conv2d(4, 8, kernel_size = 3),
            nn.ReLU(),
            nn.AvgPool2d(2, stride = 2),
            nn.Conv2d(8,16,kernel_size = 3),
            nn.ReLU(),
            nn.AvgPool2d(2, stride = 2),
            nn.Conv2d(16,32,kernel_size = 3),
            nn.ReLU(),
            nn.AvgPool2d(2, stride = 2))

        self.fc_model = nn.Sequential(
            nn.Linear(512, 256), # (N, 2592) -> (N, 512)
            nn.ReLU(),
            nn.Linear(256, 30))  # (N, 512)  -> (N, 30)) #30 classes

    def forward(self, x):
        # print(x.shape)
        x = self.cnn_model(x)
        # print(x.shape) 
        x = x.view(x.size(0), -1)
        # print(x.shape)    
        x = self.fc_model(x)
        # print(x.shape)
        return x

# %%
model = CustomNet().to(device)
loss_fn = nn.CrossEntropyLoss()
opt = optim.Adam(model.parameters(), lr=0.001)

# %%
summary(model, (1, 100, 100))
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1            [-1, 4, 98, 98]              40
#               ReLU-2            [-1, 4, 98, 98]               0
#          AvgPool2d-3            [-1, 4, 49, 49]               0
#             Conv2d-4            [-1, 8, 47, 47]             296
#               ReLU-5            [-1, 8, 47, 47]               0
#          AvgPool2d-6            [-1, 8, 23, 23]               0
#             Conv2d-7           [-1, 16, 21, 21]           1,168
#               ReLU-8           [-1, 16, 21, 21]               0
#          AvgPool2d-9           [-1, 16, 10, 10]               0
#            Conv2d-10             [-1, 32, 8, 8]           4,640
#              ReLU-11             [-1, 32, 8, 8]               0
#         AvgPool2d-12             [-1, 32, 4, 4]               0
#            Linear-13                  [-1, 256]         131,328
#              ReLU-14                  [-1, 256]               0
#            Linear-15                   [-1, 30]           7,710
# ================================================================
# Total params: 145,182
# Trainable params: 145,182
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.04
# Forward/backward pass size (MB): 1.12
# Params size (MB): 0.55
# Estimated Total Size (MB): 1.71
# ----------------------------------------------------------------

# %%
# Find total parameters and trainable parameters
total_params = sum(p.numel() for p in model.parameters())
print(f'{total_params:,} total parameters.')
total_trainable_params = sum(p.numel() for p in model.parameters() if p.requires_grad)
print(f'{total_trainable_params:,} training parameters.')
# Out:
# 145,246 total parameters.
# 145,246 training parameters.

# %%
def evaluation(dataloader):
    total, correct = 0, 0
    #keeping the network in evaluation mode 
    model.eval()
    for data in dataloader:
        inputs, labels = data
        #moving the inputs and labels to gpu
        inputs, labels = inputs.to(device), labels.to(device)
        outputs = model(inputs)
        _, pred = torch.max(outputs.data, 1)
        total += labels.size(0)
        correct += (pred == labels).sum().item()
    return 100 * correct / total

# %%
iter = []
loss_arr = []
loss_epoch_arr = []
max_epochs = 13 #epoch count
val_max_acc = 0.0
for epoch in range(max_epochs):

    for i, data in enumerate(train_loader, 0):

        inputs, labels = data
        # print(labels)
        inputs, labels = inputs.to(device), labels.to(device)
        # print()
        #forward pass
        outputs = model(inputs)
        # print('a')
        loss = loss_fn(outputs, labels)
        
        #backward and optimize
        opt.zero_grad()
        loss.backward()
        opt.step()

        if (i+1)%25 ==0:
            iter.append(i)
            loss_arr.append(loss.item())
            val_acc = evaluation(val_loader)
            train_acc = evaluation(train_loader)
            print('Epoch: %d/%d, Iterations: %d/%d, Loss: %0.4f, Test acc: %0.2f, Train acc: %0.2f' % (epoch+1, max_epochs, i+1, len(train_loader), loss.data, val_acc, train_acc))
            if val_acc>val_max_acc:
                print('Validation accuracy improved from %0.4f to %0.4f. Saving best model.....' % (val_max_acc,val_acc))
                val_max_acc = val_acc
                full_model_path = '../models/pytorch/lenet9_full.pth'
                torch.save(model, full_model_path)
            else:
                print('Validation accuracy did not improved from %0.4f. Continuing training.....' % (val_max_acc))
    loss_epoch_arr.append(loss.item())
        
    # print('Epoch: %d/%d, Test acc: %0.2f, Train acc: %0.2f' % (epoch, max_epochs, evaluation(val_loader), evaluation(train_loader)))
# Out:
# Epoch: 1/13, Iterations: 25/250, Loss: 3.2770, Test acc: 9.17, Train acc: 8.66
# Validation accuracy improved from 0.0000 to 9.1720. Saving best model.....
# Epoch: 1/13, Iterations: 50/250, Loss: 3.1466, Test acc: 7.94, Train acc: 8.56
# Validation accuracy did not improved from 9.1720. Continuing training.....
# Epoch: 1/13, Iterations: 75/250, Loss: 3.1868, Test acc: 9.17, Train acc: 8.66
# Validation accuracy did not improved from 9.1720. Continuing training.....
# Epoch: 1/13, Iterations: 100/250, Loss: 3.1466, Test acc: 7.94, Train acc: 8.56
# Validation accuracy did not improved from 9.1720. Continuing training.....
# Epoch: 1/13, Iterations: 125/250, Loss: 3.0617, Test acc: 12.06, Train acc: 12.19
# Validation accuracy improved from 9.1720 to 12.0594. Saving best model.....
# Epoch: 1/13, Iterations: 150/250, Loss: 2.6666, Test acc: 24.88, Train acc: 24.98
# Validation accuracy improved from 12.0594 to 24.8832. Saving best model.....
# Epoch: 1/13, Iterations: 175/250, Loss: 1.3520, Test acc: 46.03, Train acc: 45.90
# Validation accuracy improved from 24.8832 to 46.0297. Saving best model.....
# Epoch: 1/13, Iterations: 200/250, Loss: 1.0241, Test acc: 59.53, Train acc: 61.38
# Validation accuracy improved from 46.0297 to 59.5329. Saving best model.....
# Epoch: 1/13, Iterations: 225/250, Loss: 1.0973, Test acc: 77.32, Train acc: 78.30
# Validation accuracy improved from 59.5329 to 77.3248. Saving best model.....
# Epoch: 1/13, Iterations: 250/250, Loss: 0.6961, Test acc: 82.68, Train acc: 83.92
# Validation accuracy improved from 77.3248 to 82.6752. Saving best model.....
# Epoch: 2/13, Iterations: 25/250, Loss: 0.3996, Test acc: 81.61, Train acc: 82.46
# Validation accuracy did not improved from 82.6752. Continuing training.....
# Epoch: 2/13, Iterations: 50/250, Loss: 1.0590, Test acc: 88.79, Train acc: 89.74
# Validation accuracy improved from 82.6752 to 88.7898. Saving best model.....
# Epoch: 2/13, Iterations: 75/250, Loss: 0.2075, Test acc: 91.25, Train acc: 91.49
# Validation accuracy improved from 88.7898 to 91.2527. Saving best model.....
# Epoch: 2/13, Iterations: 100/250, Loss: 0.2192, Test acc: 92.61, Train acc: 92.39
# Validation accuracy improved from 91.2527 to 92.6115. Saving best model.....
# Epoch: 2/13, Iterations: 125/250, Loss: 0.1589, Test acc: 92.31, Train acc: 93.04
# Validation accuracy did not improved from 92.6115. Continuing training.....
# Epoch: 2/13, Iterations: 150/250, Loss: 0.3671, Test acc: 91.04, Train acc: 90.92
# Validation accuracy did not improved from 92.6115. Continuing training.....
# Epoch: 2/13, Iterations: 175/250, Loss: 0.2271, Test acc: 92.74, Train acc: 93.00
# Validation accuracy improved from 92.6115 to 92.7389. Saving best model.....
# Epoch: 2/13, Iterations: 200/250, Loss: 0.2088, Test acc: 93.46, Train acc: 93.70
# Validation accuracy improved from 92.7389 to 93.4607. Saving best model.....
# Epoch: 2/13, Iterations: 225/250, Loss: 0.1130, Test acc: 93.84, Train acc: 93.83
# Validation accuracy improved from 93.4607 to 93.8429. Saving best model.....
# Epoch: 2/13, Iterations: 250/250, Loss: 0.2858, Test acc: 94.61, Train acc: 95.39
# Validation accuracy improved from 93.8429 to 94.6072. Saving best model.....
# Epoch: 3/13, Iterations: 25/250, Loss: 0.2883, Test acc: 93.50, Train acc: 94.42
# Validation accuracy did not improved from 94.6072. Continuing training.....
# Epoch: 3/13, Iterations: 50/250, Loss: 0.1297, Test acc: 94.69, Train acc: 95.80
# Validation accuracy improved from 94.6072 to 94.6921. Saving best model.....
# Epoch: 3/13, Iterations: 75/250, Loss: 0.1118, Test acc: 94.82, Train acc: 95.08
# Validation accuracy improved from 94.6921 to 94.8195. Saving best model.....
# Epoch: 3/13, Iterations: 100/250, Loss: 0.1432, Test acc: 94.48, Train acc: 93.83
# Validation accuracy did not improved from 94.8195. Continuing training.....
# Epoch: 3/13, Iterations: 125/250, Loss: 0.2393, Test acc: 95.46, Train acc: 96.12
# Validation accuracy improved from 94.8195 to 95.4565. Saving best model.....
# Epoch: 3/13, Iterations: 150/250, Loss: 0.0833, Test acc: 95.80, Train acc: 96.26
# Validation accuracy improved from 95.4565 to 95.7962. Saving best model.....
# Epoch: 3/13, Iterations: 175/250, Loss: 0.1812, Test acc: 96.48, Train acc: 97.21
# Validation accuracy improved from 95.7962 to 96.4756. Saving best model.....
# Epoch: 3/13, Iterations: 200/250, Loss: 0.0590, Test acc: 96.43, Train acc: 97.06
# Validation accuracy did not improved from 96.4756. Continuing training.....
# Epoch: 3/13, Iterations: 225/250, Loss: 0.3138, Test acc: 95.84, Train acc: 96.33
# Validation accuracy did not improved from 96.4756. Continuing training.....
# Epoch: 3/13, Iterations: 250/250, Loss: 0.1020, Test acc: 96.73, Train acc: 96.95
# Validation accuracy improved from 96.4756 to 96.7304. Saving best model.....
# Epoch: 4/13, Iterations: 25/250, Loss: 0.2686, Test acc: 96.01, Train acc: 96.59
# Validation accuracy did not improved from 96.7304. Continuing training.....
# Epoch: 4/13, Iterations: 50/250, Loss: 0.0963, Test acc: 96.26, Train acc: 97.33
# Validation accuracy did not improved from 96.7304. Continuing training.....
# Epoch: 4/13, Iterations: 75/250, Loss: 0.0415, Test acc: 96.22, Train acc: 97.44
# Validation accuracy did not improved from 96.7304. Continuing training.....
# Epoch: 4/13, Iterations: 100/250, Loss: 0.0765, Test acc: 96.48, Train acc: 97.17
# Validation accuracy did not improved from 96.7304. Continuing training.....
# Epoch: 4/13, Iterations: 125/250, Loss: 0.0619, Test acc: 96.69, Train acc: 97.88
# Validation accuracy did not improved from 96.7304. Continuing training.....
# Epoch: 4/13, Iterations: 150/250, Loss: 0.0131, Test acc: 95.97, Train acc: 97.17
# Validation accuracy did not improved from 96.7304. Continuing training.....
# Epoch: 4/13, Iterations: 175/250, Loss: 0.1653, Test acc: 96.14, Train acc: 97.39
# Validation accuracy did not improved from 96.7304. Continuing training.....
# Epoch: 4/13, Iterations: 200/250, Loss: 0.0842, Test acc: 96.14, Train acc: 97.14
# Validation accuracy did not improved from 96.7304. Continuing training.....
# Epoch: 4/13, Iterations: 225/250, Loss: 0.0198, Test acc: 96.60, Train acc: 97.69
# Validation accuracy did not improved from 96.7304. Continuing training.....
# Epoch: 4/13, Iterations: 250/250, Loss: 0.0711, Test acc: 97.07, Train acc: 98.35
# Validation accuracy improved from 96.7304 to 97.0701. Saving best model.....
# Epoch: 5/13, Iterations: 25/250, Loss: 0.1498, Test acc: 96.48, Train acc: 97.97
# Validation accuracy did not improved from 97.0701. Continuing training.....
# Epoch: 5/13, Iterations: 50/250, Loss: 0.0191, Test acc: 95.84, Train acc: 97.20
# Validation accuracy did not improved from 97.0701. Continuing training.....
# Epoch: 5/13, Iterations: 75/250, Loss: 0.1893, Test acc: 96.39, Train acc: 98.04
# Validation accuracy did not improved from 97.0701. Continuing training.....
# Epoch: 5/13, Iterations: 100/250, Loss: 0.0463, Test acc: 96.99, Train acc: 98.17
# Validation accuracy did not improved from 97.0701. Continuing training.....
# Epoch: 5/13, Iterations: 125/250, Loss: 0.0630, Test acc: 97.32, Train acc: 98.42
# Validation accuracy improved from 97.0701 to 97.3248. Saving best model.....
# Epoch: 5/13, Iterations: 150/250, Loss: 0.0267, Test acc: 97.15, Train acc: 98.40
# Validation accuracy did not improved from 97.3248. Continuing training.....
# Epoch: 5/13, Iterations: 175/250, Loss: 0.0416, Test acc: 97.11, Train acc: 98.19
# Validation accuracy did not improved from 97.3248. Continuing training.....
# Epoch: 5/13, Iterations: 200/250, Loss: 0.3062, Test acc: 96.01, Train acc: 97.11
# Validation accuracy did not improved from 97.3248. Continuing training.....
# Epoch: 5/13, Iterations: 225/250, Loss: 0.1653, Test acc: 96.60, Train acc: 97.89
# Validation accuracy did not improved from 97.3248. Continuing training.....
# Epoch: 5/13, Iterations: 250/250, Loss: 0.0700, Test acc: 96.35, Train acc: 97.89
# Validation accuracy did not improved from 97.3248. Continuing training.....
# Epoch: 6/13, Iterations: 25/250, Loss: 0.0169, Test acc: 96.94, Train acc: 98.64
# Validation accuracy did not improved from 97.3248. Continuing training.....
# Epoch: 6/13, Iterations: 50/250, Loss: 0.0043, Test acc: 97.41, Train acc: 98.86
# Validation accuracy improved from 97.3248 to 97.4098. Saving best model.....
# Epoch: 6/13, Iterations: 75/250, Loss: 0.0236, Test acc: 97.03, Train acc: 98.92
# Validation accuracy did not improved from 97.4098. Continuing training.....
# Epoch: 6/13, Iterations: 100/250, Loss: 0.0120, Test acc: 97.24, Train acc: 98.64
# Validation accuracy did not improved from 97.4098. Continuing training.....
# Epoch: 6/13, Iterations: 125/250, Loss: 0.0469, Test acc: 97.15, Train acc: 98.76
# Validation accuracy did not improved from 97.4098. Continuing training.....
# Epoch: 6/13, Iterations: 150/250, Loss: 0.0026, Test acc: 97.58, Train acc: 98.80
# Validation accuracy improved from 97.4098 to 97.5796. Saving best model.....
# Epoch: 6/13, Iterations: 175/250, Loss: 0.0044, Test acc: 97.28, Train acc: 98.94
# Validation accuracy did not improved from 97.5796. Continuing training.....
# Epoch: 6/13, Iterations: 200/250, Loss: 0.0055, Test acc: 95.75, Train acc: 97.76
# Validation accuracy did not improved from 97.5796. Continuing training.....
# Epoch: 6/13, Iterations: 225/250, Loss: 0.0202, Test acc: 97.24, Train acc: 98.92
# Validation accuracy did not improved from 97.5796. Continuing training.....
# Epoch: 6/13, Iterations: 250/250, Loss: 0.0099, Test acc: 96.99, Train acc: 98.64
# Validation accuracy did not improved from 97.5796. Continuing training.....
# Epoch: 7/13, Iterations: 25/250, Loss: 0.1350, Test acc: 97.66, Train acc: 99.10
# Validation accuracy improved from 97.5796 to 97.6645. Saving best model.....
# Epoch: 7/13, Iterations: 50/250, Loss: 0.1608, Test acc: 97.58, Train acc: 99.03
# Validation accuracy did not improved from 97.6645. Continuing training.....
# Epoch: 7/13, Iterations: 75/250, Loss: 0.0077, Test acc: 96.77, Train acc: 98.64
# Validation accuracy did not improved from 97.6645. Continuing training.....
# Epoch: 7/13, Iterations: 100/250, Loss: 0.0193, Test acc: 96.90, Train acc: 98.38
# Validation accuracy did not improved from 97.6645. Continuing training.....
# Epoch: 7/13, Iterations: 125/250, Loss: 0.0271, Test acc: 96.73, Train acc: 98.44
# Validation accuracy did not improved from 97.6645. Continuing training.....
# Epoch: 7/13, Iterations: 150/250, Loss: 0.0022, Test acc: 96.99, Train acc: 98.74
# Validation accuracy did not improved from 97.6645. Continuing training.....
# Epoch: 7/13, Iterations: 175/250, Loss: 0.0156, Test acc: 97.28, Train acc: 99.08
# Validation accuracy did not improved from 97.6645. Continuing training.....
# Epoch: 7/13, Iterations: 200/250, Loss: 0.0488, Test acc: 97.03, Train acc: 98.74
# Validation accuracy did not improved from 97.6645. Continuing training.....
# Epoch: 7/13, Iterations: 225/250, Loss: 0.0043, Test acc: 97.58, Train acc: 99.24
# Validation accuracy did not improved from 97.6645. Continuing training.....
# Epoch: 7/13, Iterations: 250/250, Loss: 0.0056, Test acc: 96.56, Train acc: 98.59
# Validation accuracy did not improved from 97.6645. Continuing training.....
# Epoch: 8/13, Iterations: 25/250, Loss: 0.0511, Test acc: 97.49, Train acc: 99.33
# Validation accuracy did not improved from 97.6645. Continuing training.....
# Epoch: 8/13, Iterations: 50/250, Loss: 0.0651, Test acc: 96.82, Train acc: 98.53
# Validation accuracy did not improved from 97.6645. Continuing training.....
# Epoch: 8/13, Iterations: 75/250, Loss: 0.0058, Test acc: 96.60, Train acc: 98.47
# Validation accuracy did not improved from 97.6645. Continuing training.....
# Epoch: 8/13, Iterations: 100/250, Loss: 0.1355, Test acc: 97.37, Train acc: 99.04
# Validation accuracy did not improved from 97.6645. Continuing training.....
# Epoch: 8/13, Iterations: 125/250, Loss: 0.0709, Test acc: 96.82, Train acc: 98.51
# Validation accuracy did not improved from 97.6645. Continuing training.....
# Epoch: 8/13, Iterations: 150/250, Loss: 0.0104, Test acc: 97.24, Train acc: 99.20
# Validation accuracy did not improved from 97.6645. Continuing training.....
# Epoch: 8/13, Iterations: 175/250, Loss: 0.0100, Test acc: 96.94, Train acc: 98.86
# Validation accuracy did not improved from 97.6645. Continuing training.....
# Epoch: 8/13, Iterations: 200/250, Loss: 0.1015, Test acc: 97.28, Train acc: 98.88
# Validation accuracy did not improved from 97.6645. Continuing training.....
# Epoch: 8/13, Iterations: 225/250, Loss: 0.0513, Test acc: 97.15, Train acc: 99.09
# Validation accuracy did not improved from 97.6645. Continuing training.....
# Epoch: 8/13, Iterations: 250/250, Loss: 0.0391, Test acc: 96.82, Train acc: 98.99
# Validation accuracy did not improved from 97.6645. Continuing training.....
# Epoch: 9/13, Iterations: 25/250, Loss: 0.0142, Test acc: 97.62, Train acc: 99.36
# Validation accuracy did not improved from 97.6645. Continuing training.....
# Epoch: 9/13, Iterations: 50/250, Loss: 0.0013, Test acc: 97.83, Train acc: 99.26
# Validation accuracy improved from 97.6645 to 97.8344. Saving best model.....
# Epoch: 9/13, Iterations: 75/250, Loss: 0.0070, Test acc: 97.58, Train acc: 99.29
# Validation accuracy did not improved from 97.8344. Continuing training.....
# Epoch: 9/13, Iterations: 100/250, Loss: 0.0381, Test acc: 97.37, Train acc: 99.17
# Validation accuracy did not improved from 97.8344. Continuing training.....
# Epoch: 9/13, Iterations: 125/250, Loss: 0.0172, Test acc: 96.65, Train acc: 98.56
# Validation accuracy did not improved from 97.8344. Continuing training.....
# Epoch: 9/13, Iterations: 150/250, Loss: 0.0570, Test acc: 97.03, Train acc: 99.09
# Validation accuracy did not improved from 97.8344. Continuing training.....
# Epoch: 9/13, Iterations: 175/250, Loss: 0.0027, Test acc: 97.45, Train acc: 99.20
# Validation accuracy did not improved from 97.8344. Continuing training.....
# Epoch: 9/13, Iterations: 200/250, Loss: 0.0020, Test acc: 97.79, Train acc: 99.34
# Validation accuracy did not improved from 97.8344. Continuing training.....
# Epoch: 9/13, Iterations: 225/250, Loss: 0.0033, Test acc: 97.71, Train acc: 99.51
# Validation accuracy did not improved from 97.8344. Continuing training.....
# Epoch: 9/13, Iterations: 250/250, Loss: 0.0116, Test acc: 96.73, Train acc: 98.86
# Validation accuracy did not improved from 97.8344. Continuing training.....
# Epoch: 10/13, Iterations: 25/250, Loss: 0.0036, Test acc: 96.77, Train acc: 99.01
# Validation accuracy did not improved from 97.8344. Continuing training.....
# Epoch: 10/13, Iterations: 50/250, Loss: 0.0007, Test acc: 95.88, Train acc: 98.40
# Validation accuracy did not improved from 97.8344. Continuing training.....
# Epoch: 10/13, Iterations: 75/250, Loss: 0.0072, Test acc: 97.11, Train acc: 99.00
# Validation accuracy did not improved from 97.8344. Continuing training.....
# Epoch: 10/13, Iterations: 100/250, Loss: 0.0032, Test acc: 97.75, Train acc: 99.04
# Validation accuracy did not improved from 97.8344. Continuing training.....
# Epoch: 10/13, Iterations: 125/250, Loss: 0.0046, Test acc: 97.28, Train acc: 99.35
# Validation accuracy did not improved from 97.8344. Continuing training.....
# Epoch: 10/13, Iterations: 150/250, Loss: 0.0083, Test acc: 97.49, Train acc: 99.47
# Validation accuracy did not improved from 97.8344. Continuing training.....
# Epoch: 10/13, Iterations: 175/250, Loss: 0.0980, Test acc: 97.45, Train acc: 99.46
# Validation accuracy did not improved from 97.8344. Continuing training.....
# Epoch: 10/13, Iterations: 200/250, Loss: 0.0095, Test acc: 97.49, Train acc: 99.58
# Validation accuracy did not improved from 97.8344. Continuing training.....
# Epoch: 10/13, Iterations: 225/250, Loss: 0.0341, Test acc: 96.52, Train acc: 98.31
# Validation accuracy did not improved from 97.8344. Continuing training.....
# Epoch: 10/13, Iterations: 250/250, Loss: 0.0410, Test acc: 96.43, Train acc: 98.47
# Validation accuracy did not improved from 97.8344. Continuing training.....
# Epoch: 11/13, Iterations: 25/250, Loss: 0.0025, Test acc: 97.37, Train acc: 99.06
# Validation accuracy did not improved from 97.8344. Continuing training.....
# Epoch: 11/13, Iterations: 50/250, Loss: 0.0017, Test acc: 97.75, Train acc: 99.59
# Validation accuracy did not improved from 97.8344. Continuing training.....
# Epoch: 11/13, Iterations: 75/250, Loss: 0.0020, Test acc: 97.79, Train acc: 99.65
# Validation accuracy did not improved from 97.8344. Continuing training.....
# Epoch: 11/13, Iterations: 100/250, Loss: 0.0230, Test acc: 98.00, Train acc: 99.60
# Validation accuracy improved from 97.8344 to 98.0042. Saving best model.....
# Epoch: 11/13, Iterations: 125/250, Loss: 0.0081, Test acc: 97.92, Train acc: 99.28
# Validation accuracy did not improved from 98.0042. Continuing training.....
# Epoch: 11/13, Iterations: 150/250, Loss: 0.0093, Test acc: 97.62, Train acc: 99.39
# Validation accuracy did not improved from 98.0042. Continuing training.....
# Epoch: 11/13, Iterations: 175/250, Loss: 0.0651, Test acc: 98.00, Train acc: 99.49
# Validation accuracy did not improved from 98.0042. Continuing training.....
# Epoch: 11/13, Iterations: 200/250, Loss: 0.0014, Test acc: 98.13, Train acc: 99.74
# Validation accuracy improved from 98.0042 to 98.1316. Saving best model.....
# Epoch: 11/13, Iterations: 225/250, Loss: 0.0060, Test acc: 97.49, Train acc: 99.26
# Validation accuracy did not improved from 98.1316. Continuing training.....
# Epoch: 11/13, Iterations: 250/250, Loss: 0.0632, Test acc: 97.49, Train acc: 99.66
# Validation accuracy did not improved from 98.1316. Continuing training.....
# Epoch: 12/13, Iterations: 25/250, Loss: 0.0420, Test acc: 97.92, Train acc: 99.78
# Validation accuracy did not improved from 98.1316. Continuing training.....
# Epoch: 12/13, Iterations: 50/250, Loss: 0.0091, Test acc: 97.37, Train acc: 99.31
# Validation accuracy did not improved from 98.1316. Continuing training.....
# Epoch: 12/13, Iterations: 75/250, Loss: 0.0000, Test acc: 98.05, Train acc: 99.56
# Validation accuracy did not improved from 98.1316. Continuing training.....
# Epoch: 12/13, Iterations: 100/250, Loss: 0.0937, Test acc: 97.66, Train acc: 99.58
# Validation accuracy did not improved from 98.1316. Continuing training.....
# Epoch: 12/13, Iterations: 125/250, Loss: 0.0081, Test acc: 97.71, Train acc: 99.70
# Validation accuracy did not improved from 98.1316. Continuing training.....
# Epoch: 12/13, Iterations: 150/250, Loss: 0.0001, Test acc: 97.37, Train acc: 99.49
# Validation accuracy did not improved from 98.1316. Continuing training.....
# Epoch: 12/13, Iterations: 175/250, Loss: 0.0123, Test acc: 97.62, Train acc: 99.69
# Validation accuracy did not improved from 98.1316. Continuing training.....
# Epoch: 12/13, Iterations: 200/250, Loss: 0.1057, Test acc: 97.66, Train acc: 99.74
# Validation accuracy did not improved from 98.1316. Continuing training.....
# Epoch: 12/13, Iterations: 225/250, Loss: 0.0005, Test acc: 97.71, Train acc: 99.39
# Validation accuracy did not improved from 98.1316. Continuing training.....
# Epoch: 12/13, Iterations: 250/250, Loss: 0.0006, Test acc: 98.17, Train acc: 99.84
# Validation accuracy improved from 98.1316 to 98.1741. Saving best model.....
# Epoch: 13/13, Iterations: 25/250, Loss: 0.0020, Test acc: 98.00, Train acc: 99.80
# Validation accuracy did not improved from 98.1741. Continuing training.....
# Epoch: 13/13, Iterations: 50/250, Loss: 0.0027, Test acc: 97.96, Train acc: 99.78
# Validation accuracy did not improved from 98.1741. Continuing training.....
# Epoch: 13/13, Iterations: 75/250, Loss: 0.0002, Test acc: 98.13, Train acc: 99.91
# Validation accuracy did not improved from 98.1741. Continuing training.....
# Epoch: 13/13, Iterations: 100/250, Loss: 0.0615, Test acc: 97.79, Train acc: 99.53
# Validation accuracy did not improved from 98.1741. Continuing training.....
# Epoch: 13/13, Iterations: 125/250, Loss: 0.0116, Test acc: 96.73, Train acc: 98.94
# Validation accuracy did not improved from 98.1741. Continuing training.....
# Epoch: 13/13, Iterations: 150/250, Loss: 0.0004, Test acc: 97.45, Train acc: 99.36
# Validation accuracy did not improved from 98.1741. Continuing training.....
# Epoch: 13/13, Iterations: 175/250, Loss: 0.0024, Test acc: 97.75, Train acc: 99.54
# Validation accuracy did not improved from 98.1741. Continuing training.....
# Epoch: 13/13, Iterations: 200/250, Loss: 0.1368, Test acc: 97.96, Train acc: 99.51
# Validation accuracy did not improved from 98.1741. Continuing training.....
# Epoch: 13/13, Iterations: 225/250, Loss: 0.0193, Test acc: 97.24, Train acc: 99.34
# Validation accuracy did not improved from 98.1741. Continuing training.....
# Epoch: 13/13, Iterations: 250/250, Loss: 0.0004, Test acc: 97.62, Train acc: 99.55
# Validation accuracy did not improved from 98.1741. Continuing training.....

# %%
plt.plot(loss_epoch_arr)
plt.show()

# %%
plt.plot(loss_arr)
plt.show()

# %%
model_path = '../models/pytorch/lenet9.pth'
torch.save(model.state_dict(), model_path)

# %%
full_model_path = '../models/pytorch/lenet9_full.pth'
torch.save(model, full_model_path)

# %% [markdown]
# ## Inference

# %%
from PIL import Image
img = Image.open('letters/A/7531.jpg')
# img = cv2.imread('letters/2/24.jpg',-1)
plt.imshow(img,cmap='gray')

# %%
img_t = image_transforms["train"](img)
batch_t = torch.unsqueeze(img_t, 0)

# %%
full_model_path = '../models/pytorch/lenet5_full.pth'
model = torch.load(full_model_path)
model.eval()
# Out:
# CustomNet(
#   (cnn_model): Sequential(
#     (0): Conv2d(1, 4, kernel_size=(5, 5), stride=(1, 1))
#     (1): ReLU()
#     (2): AvgPool2d(kernel_size=2, stride=2, padding=0)
#     (3): Conv2d(4, 8, kernel_size=(3, 3), stride=(1, 1))
#     (4): ReLU()
#     (5): AvgPool2d(kernel_size=2, stride=2, padding=0)
#     (6): Conv2d(8, 16, kernel_size=(3, 3), stride=(1, 1))
#     (7): ReLU()
#     (8): AvgPool2d(kernel_size=2, stride=2, padding=0)
#     (9): Conv2d(16, 32, kernel_size=(3, 3), stride=(1, 1))
#     (10): ReLU()
#     (11): AvgPool2d(kernel_size=2, stride=2, padding=0)
#   )
#   (fc_model): Sequential(
#     (0): Linear(in_features=512, out_features=256, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=256, out_features=30, bias=True)
#   )
# )

# %%
out = model(batch_t.to(device))
print(out.shape)
# Out:
# torch.Size([1, 30])

# %%
prediction = int(torch.max(out.cpu().data, 1)[1].numpy())
print(prediction)
# Out:
# 8

# %%
letter = idx2class[prediction]
print(letter)
# Out:
# A
