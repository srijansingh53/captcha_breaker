# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import os
os.chdir('/content/drive/My Drive/project_captcha/dataset/')
# !ls
# Out:
# captcha_labelled  combined  deskewed  label.csv  letters  processed

# %%
import cv2
import numpy as np
import pandas as pd

import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torchvision import transforms, datasets, models
from torch.autograd import Variable
from torch.utils.data import DataLoader, Dataset, sampler, random_split, SubsetRandomSampler, WeightedRandomSampler
from torchsummary import summary


import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
np.random.seed(0)
torch.manual_seed(0)

# %%
''' Declaring important parameters '''

data_dir = 'letters'
nThreads = 4
batch_size = 32

# %% [markdown]
# ## Loading/Splitting Dataset

# %%
''' Loading dataset and splitting it into train and test set '''
def load_split_train_test(datadir, valid_size = .2):

    train_transforms = transforms.Compose([transforms.Resize(100),
                                           transforms.ToTensor(),
                                           ])
    test_transforms = transforms.Compose([transforms.Resize(100),
                                          transforms.ToTensor(),
                                          ])
    train_data = datasets.ImageFolder(datadir, transform=train_transforms)
    test_data = datasets.ImageFolder(datadir, transform=test_transforms)
    num_train = len(train_data)
    indices = list(range(num_train))
    split = int(np.floor(valid_size * num_train))
    np.random.shuffle(indices)

    train_idx, test_idx = indices[split:], indices[:split]
    train_sampler = sampler.SubsetRandomSampler(train_idx)
    test_sampler = sampler.SubsetRandomSampler(test_idx)
    trainloader = DataLoader(train_data,
                   sampler=train_sampler, batch_size=64)
    testloader = DataLoader(test_data,
                   sampler=test_sampler, batch_size=64)
    return trainloader, testloader

trainloader, testloader = load_split_train_test(data_dir, .2)
print(testloader.dataset.classes)
# Out:
# ['2', '3', '4', '5', '6', '7', '8', '9', 'A', 'C', 'D', 'E', 'F', 'G', 'H', 'J', 'K', 'M', 'N', 'P', 'Q', 'R', 'S', 'T', 'U', 'V', 'W', 'X', 'Y', 'Z']

# %% [markdown]
# Another method of splitting

# %%
image_transforms = {
    "train": transforms.Compose([
        transforms.Grayscale(),
        transforms.Resize((100, 100)),
        transforms.ToTensor()
    ])
}

# %%
letters_dataset = datasets.ImageFolder(
                              root = data_dir,
                              transform = image_transforms["train"]
                       )

# %%
letters_dataset
# Out:
# Dataset ImageFolder
#     Number of datapoints: 10355
#     Root location: letters
#     StandardTransform
# Transform: Compose(
#                Grayscale(num_output_channels=1)
#                Resize(size=(100, 100), interpolation=PIL.Image.BILINEAR)
#                ToTensor()
#            )

# %%
print(letters_dataset.classes)
print(letters_dataset.class_to_idx)
# Out:
# ['2', '3', '4', '5', '6', '7', '8', '9', 'A', 'C', 'D', 'E', 'F', 'G', 'H', 'J', 'K', 'M', 'N', 'P', 'Q', 'R', 'S', 'T', 'U', 'V', 'W', 'X', 'Y', 'Z']
# {'2': 0, '3': 1, '4': 2, '5': 3, '6': 4, '7': 5, '8': 6, '9': 7, 'A': 8, 'C': 9, 'D': 10, 'E': 11, 'F': 12, 'G': 13, 'H': 14, 'J': 15, 'K': 16, 'M': 17, 'N': 18, 'P': 19, 'Q': 20, 'R': 21, 'S': 22, 'T': 23, 'U': 24, 'V': 25, 'W': 26, 'X': 27, 'Y': 28, 'Z': 29}

# %%
idx2class = {v: k for k, v in letters_dataset.class_to_idx.items()}
print(idx2class)
# Out:
# {0: '2', 1: '3', 2: '4', 3: '5', 4: '6', 5: '7', 6: '8', 7: '9', 8: 'A', 9: 'C', 10: 'D', 11: 'E', 12: 'F', 13: 'G', 14: 'H', 15: 'J', 16: 'K', 17: 'M', 18: 'N', 19: 'P', 20: 'Q', 21: 'R', 22: 'S', 23: 'T', 24: 'U', 25: 'V', 26: 'W', 27: 'X', 28: 'Y', 29: 'Z'}

# %%
def get_class_distribution(dataset_obj):
    count_dict = {k:0 for k,v in dataset_obj.class_to_idx.items()}
    
    for element in dataset_obj:
        y_lbl = element[1]
        y_lbl = idx2class[y_lbl]
        count_dict[y_lbl] += 1
            
    return count_dict
# print("Distribution of classes: \n", get_class_distribution(letters_dataset))

# %%
plt.figure(figsize=(15,8))
sns.barplot(data = pd.DataFrame.from_dict([get_class_distribution(letters_dataset)]).melt(),
            x = "variable", y="value", hue="variable").set_title('Letters Class Distribution')

# %% [markdown]
# Random split

# %%
train_dataset, val_dataset = random_split(letters_dataset, (9000, 1355))

train_loader = DataLoader(dataset=train_dataset, shuffle=True, batch_size=32)
val_loader = DataLoader(dataset=val_dataset, shuffle=False, batch_size=32)
print("Length of the train_loader:", len(train_loader))
print("Length of the val_loader:", len(val_loader))
# Out:
# Length of the train_loader: 282
# Length of the val_loader: 43

# %%
''' Vizualize Images from dataloader '''

dataiter = iter(train_loader)
images, labels = dataiter.next()
print(type(images))
print(images.shape)
print(labels.shape)
image = np.transpose(images[0].numpy(), (1, 2, 0))
image = image.reshape(100,100)
print(set(image.flatten()))
plt.imshow(image, cmap='gray')

# %% [markdown]
# Model

# %%
device = torch.device("cuda" if torch.cuda.is_available() 
                                  else "cpu")
print(device)
# Out:
# cuda

# %% [markdown]
# ##Training

# %%
class CustomNet(nn.Module):
    def __init__(self):
        super(CustomNet, self).__init__()
        self.cnn_model = nn.Sequential(
            nn.Conv2d(1, 4, kernel_size = 5),
            nn.ReLU(),
            nn.AvgPool2d(2, stride = 2),
            nn.Conv2d(4, 8, kernel_size = 3),
            nn.ReLU(),
            nn.AvgPool2d(2, stride = 2),
            nn.Conv2d(8,16,kernel_size = 3),
            nn.ReLU(),
            nn.AvgPool2d(2, stride = 2),
            nn.Conv2d(16,32,kernel_size = 3),
            nn.ReLU(),
            nn.AvgPool2d(2, stride = 2))

        self.fc_model = nn.Sequential(
            nn.Linear(512, 256), # (N, 2592) -> (N, 512)
            nn.ReLU(),
            nn.Linear(256, 30))  # (N, 512)  -> (N, 30)) #30 classes

    def forward(self, x):
        # print(x.shape)
        x = self.cnn_model(x)
        # print(x.shape) 
        x = x.view(x.size(0), -1)
        # print(x.shape)    
        x = self.fc_model(x)
        # print(x.shape)
        return x

# %%
model = CustomNet().to(device)
loss_fn = nn.CrossEntropyLoss()
opt = optim.Adam(model.parameters(), lr=0.001)

# %%
summary(model, (1, 100, 100))
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1            [-1, 4, 96, 96]             104
#               ReLU-2            [-1, 4, 96, 96]               0
#          AvgPool2d-3            [-1, 4, 48, 48]               0
#             Conv2d-4            [-1, 8, 46, 46]             296
#               ReLU-5            [-1, 8, 46, 46]               0
#          AvgPool2d-6            [-1, 8, 23, 23]               0
#             Conv2d-7           [-1, 16, 21, 21]           1,168
#               ReLU-8           [-1, 16, 21, 21]               0
#          AvgPool2d-9           [-1, 16, 10, 10]               0
#            Conv2d-10             [-1, 32, 8, 8]           4,640
#              ReLU-11             [-1, 32, 8, 8]               0
#         AvgPool2d-12             [-1, 32, 4, 4]               0
#            Linear-13                  [-1, 256]         131,328
#              ReLU-14                  [-1, 256]               0
#            Linear-15                   [-1, 30]           7,710
# ================================================================
# Total params: 145,246
# Trainable params: 145,246
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.04
# Forward/backward pass size (MB): 1.08
# Params size (MB): 0.55
# Estimated Total Size (MB): 1.67
# ----------------------------------------------------------------

# %%
# Find total parameters and trainable parameters
total_params = sum(p.numel() for p in model.parameters())
print(f'{total_params:,} total parameters.')
total_trainable_params = sum(p.numel() for p in model.parameters() if p.requires_grad)
print(f'{total_trainable_params:,} training parameters.')
# Out:
# 145,246 total parameters.
# 145,246 training parameters.

# %%
def evaluation(dataloader):
    total, correct = 0, 0
    #keeping the network in evaluation mode 
    model.eval()
    for data in dataloader:
        inputs, labels = data
        #moving the inputs and labels to gpu
        inputs, labels = inputs.to(device), labels.to(device)
        outputs = model(inputs)
        _, pred = torch.max(outputs.data, 1)
        total += labels.size(0)
        correct += (pred == labels).sum().item()
    return 100 * correct / total

# %%
iter = []
loss_arr = []
loss_epoch_arr = []
max_epochs = 10 #epoch count

for epoch in range(max_epochs):

    for i, data in enumerate(train_loader, 0):

        inputs, labels = data
        # print(labels)
        inputs, labels = inputs.to(device), labels.to(device)
        # print()
        #forward pass
        outputs = model(inputs)
        # print('a')
        loss = loss_fn(outputs, labels)
        
        #backward and optimize
        opt.zero_grad()
        loss.backward()
        opt.step()

        if (i+1)%25 ==0:
            iter.append(i)
            loss_arr.append(loss.item())
            print('Epoch: %d/%d, Iterations: %d/%d, Loss: %0.4f, Test acc: %0.2f, Train acc: %0.2f' % (epoch+1, max_epochs, i+1, len(train_loader), loss.data, evaluation(val_loader), evaluation(train_loader)))
    loss_epoch_arr.append(loss.item())
        
    # print('Epoch: %d/%d, Test acc: %0.2f, Train acc: %0.2f' % (epoch, max_epochs, evaluation(val_loader), evaluation(train_loader)))
# Out:
# Epoch: 1/10, Iterations: 25/282, Loss: 3.0264, Test acc: 16.38, Train acc: 17.02
# Epoch: 1/10, Iterations: 50/282, Loss: 2.2950, Test acc: 34.98, Train acc: 34.06
# Epoch: 1/10, Iterations: 75/282, Loss: 1.3949, Test acc: 51.66, Train acc: 52.22
# Epoch: 1/10, Iterations: 100/282, Loss: 1.0049, Test acc: 67.08, Train acc: 68.63
# Epoch: 1/10, Iterations: 125/282, Loss: 0.8401, Test acc: 81.40, Train acc: 81.32
# Epoch: 1/10, Iterations: 150/282, Loss: 0.4891, Test acc: 78.67, Train acc: 79.33
# Epoch: 1/10, Iterations: 175/282, Loss: 1.2003, Test acc: 83.62, Train acc: 84.43
# Epoch: 9/10, Iterations: 100/282, Loss: 0.0074, Test acc: 97.64, Train acc: 98.81
# Epoch: 9/10, Iterations: 125/282, Loss: 0.0027, Test acc: 97.56, Train acc: 99.03
# Epoch: 9/10, Iterations: 150/282, Loss: 0.0451, Test acc: 97.86, Train acc: 99.18
# Epoch: 9/10, Iterations: 175/282, Loss: 0.0008, Test acc: 98.15, Train acc: 99.50
# Epoch: 9/10, Iterations: 200/282, Loss: 0.0007, Test acc: 98.30, Train acc: 99.61
# Epoch: 9/10, Iterations: 225/282, Loss: 0.0292, Test acc: 98.30, Train acc: 99.52
# Epoch: 9/10, Iterations: 250/282, Loss: 0.0091, Test acc: 98.08, Train acc: 99.33
# Epoch: 9/10, Iterations: 275/282, Loss: 0.0295, Test acc: 97.27, Train acc: 99.27
# Epoch: 10/10, Iterations: 25/282, Loss: 0.0078, Test acc: 98.38, Train acc: 99.54
# Epoch: 10/10, Iterations: 50/282, Loss: 0.0103, Test acc: 97.79, Train acc: 99.37
# Epoch: 10/10, Iterations: 75/282, Loss: 0.0107, Test acc: 97.05, Train acc: 99.16
# Epoch: 10/10, Iterations: 100/282, Loss: 0.0035, Test acc: 98.38, Train acc: 99.53
# Epoch: 10/10, Iterations: 125/282, Loss: 0.0017, Test acc: 98.67, Train acc: 99.71
# Epoch: 10/10, Iterations: 150/282, Loss: 0.0418, Test acc: 98.23, Train acc: 99.44
# Epoch: 10/10, Iterations: 175/282, Loss: 0.0008, Test acc: 98.15, Train acc: 99.57
# Epoch: 10/10, Iterations: 200/282, Loss: 0.0075, Test acc: 97.79, Train acc: 99.30
# Epoch: 10/10, Iterations: 225/282, Loss: 0.0018, Test acc: 97.79, Train acc: 99.61
# Epoch: 10/10, Iterations: 250/282, Loss: 0.1958, Test acc: 97.86, Train acc: 99.37
# Epoch: 10/10, Iterations: 275/282, Loss: 0.0003, Test acc: 96.90, Train acc: 98.74

# %%
plt.plot(loss_epoch_arr)
plt.show()

# %%
plt.plot(loss_arr)
plt.show()

# %%
model_path = '../models/pytorch/lenet5.pth'
torch.save(model.state_dict(), model_path)

# %%
full_model_path = '../models/pytorch/lenet5_full.pth'
torch.save(model, full_model_path)

# %% [markdown]
# ## Inference

# %%
from PIL import Image
img = Image.open('letters/A/7531.jpg')
# img = cv2.imread('letters/2/24.jpg',-1)
plt.imshow(img,cmap='gray')

# %%
img_t = image_transforms["train"](img)
batch_t = torch.unsqueeze(img_t, 0)

# %%
full_model_path = '../models/pytorch/lenet5_full.pth'
model = torch.load(full_model_path)
model.eval()
# Out:
# CustomNet(
#   (cnn_model): Sequential(
#     (0): Conv2d(1, 4, kernel_size=(5, 5), stride=(1, 1))
#     (1): ReLU()
#     (2): AvgPool2d(kernel_size=2, stride=2, padding=0)
#     (3): Conv2d(4, 8, kernel_size=(3, 3), stride=(1, 1))
#     (4): ReLU()
#     (5): AvgPool2d(kernel_size=2, stride=2, padding=0)
#     (6): Conv2d(8, 16, kernel_size=(3, 3), stride=(1, 1))
#     (7): ReLU()
#     (8): AvgPool2d(kernel_size=2, stride=2, padding=0)
#     (9): Conv2d(16, 32, kernel_size=(3, 3), stride=(1, 1))
#     (10): ReLU()
#     (11): AvgPool2d(kernel_size=2, stride=2, padding=0)
#   )
#   (fc_model): Sequential(
#     (0): Linear(in_features=512, out_features=256, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=256, out_features=30, bias=True)
#   )
# )

# %%
out = model(batch_t.to(device))
print(out.shape)
# Out:
# torch.Size([1, 30])

# %%
prediction = int(torch.max(out.cpu().data, 1)[1].numpy())
print(prediction)
# Out:
# 8

# %%
letter = idx2class[prediction]
print(letter)
# Out:
# A
