# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
import os
os.chdir('/content/drive/My Drive/project_captcha/dataset/')
# !ls
# Out:
# captcha_labelled  combined  deskewed  label.csv  letters  processed

# %%
import cv2
import numpy as np
import pandas as pd

import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torchvision import transforms, datasets, models
from torch.autograd import Variable
from torch.utils.data import DataLoader, Dataset, sampler, random_split, SubsetRandomSampler, WeightedRandomSampler
from torchsummary import summary


import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
# Out:
# /usr/local/lib/python3.6/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %%
np.random.seed(0)
torch.manual_seed(0)

# %%
''' Declaring important parameters '''

data_dir = 'letters'
nThreads = 4
batch_size = 32

# %% [markdown]
# ## Loading/Splitting Dataset

# %%
''' Loading dataset and splitting it into train and test set '''
def load_split_train_test(datadir, valid_size = .2):

    train_transforms = transforms.Compose([transforms.Resize(100),
                                           transforms.ToTensor(),
                                           ])
    test_transforms = transforms.Compose([transforms.Resize(100),
                                          transforms.ToTensor(),
                                          ])
    train_data = datasets.ImageFolder(datadir, transform=train_transforms)
    test_data = datasets.ImageFolder(datadir, transform=test_transforms)
    num_train = len(train_data)
    indices = list(range(num_train))
    split = int(np.floor(valid_size * num_train))
    np.random.shuffle(indices)

    train_idx, test_idx = indices[split:], indices[:split]
    train_sampler = sampler.SubsetRandomSampler(train_idx)
    test_sampler = sampler.SubsetRandomSampler(test_idx)
    trainloader = DataLoader(train_data,
                   sampler=train_sampler, batch_size=64)
    testloader = DataLoader(test_data,
                   sampler=test_sampler, batch_size=64)
    return trainloader, testloader

trainloader, testloader = load_split_train_test(data_dir, .2)
print(testloader.dataset.classes)
# Out:
# ['2', '3', '4', '5', '6', '7', '8', '9', 'A', 'C', 'D', 'E', 'F', 'G', 'H', 'J', 'K', 'M', 'N', 'P', 'Q', 'R', 'S', 'T', 'U', 'V', 'W', 'X', 'Y', 'Z']

# %% [markdown]
# Another method of splitting

# %%
image_transforms = {
    "train": transforms.Compose([
        transforms.Grayscale(),
        transforms.Resize((100, 100)),
        transforms.ToTensor()
    ])
}

# %%
letters_dataset = datasets.ImageFolder(
                              root = data_dir,
                              transform = image_transforms["train"]
                       )

# %%
letters_dataset
# Out:
# Dataset ImageFolder
#     Number of datapoints: 10355
#     Root location: letters
#     StandardTransform
# Transform: Compose(
#                Grayscale(num_output_channels=1)
#                Resize(size=(100, 100), interpolation=PIL.Image.BILINEAR)
#                ToTensor()
#            )

# %%
print(letters_dataset.classes)
print(letters_dataset.class_to_idx)
# Out:
# ['2', '3', '4', '5', '6', '7', '8', '9', 'A', 'C', 'D', 'E', 'F', 'G', 'H', 'J', 'K', 'M', 'N', 'P', 'Q', 'R', 'S', 'T', 'U', 'V', 'W', 'X', 'Y', 'Z']
# {'2': 0, '3': 1, '4': 2, '5': 3, '6': 4, '7': 5, '8': 6, '9': 7, 'A': 8, 'C': 9, 'D': 10, 'E': 11, 'F': 12, 'G': 13, 'H': 14, 'J': 15, 'K': 16, 'M': 17, 'N': 18, 'P': 19, 'Q': 20, 'R': 21, 'S': 22, 'T': 23, 'U': 24, 'V': 25, 'W': 26, 'X': 27, 'Y': 28, 'Z': 29}

# %%
idx2class = {v: k for k, v in letters_dataset.class_to_idx.items()}
print(idx2class)
# Out:
# {0: '2', 1: '3', 2: '4', 3: '5', 4: '6', 5: '7', 6: '8', 7: '9', 8: 'A', 9: 'C', 10: 'D', 11: 'E', 12: 'F', 13: 'G', 14: 'H', 15: 'J', 16: 'K', 17: 'M', 18: 'N', 19: 'P', 20: 'Q', 21: 'R', 22: 'S', 23: 'T', 24: 'U', 25: 'V', 26: 'W', 27: 'X', 28: 'Y', 29: 'Z'}

# %%
def get_class_distribution(dataset_obj):
    count_dict = {k:0 for k,v in dataset_obj.class_to_idx.items()}
    
    for element in dataset_obj:
        y_lbl = element[1]
        y_lbl = idx2class[y_lbl]
        count_dict[y_lbl] += 1
            
    return count_dict
# print("Distribution of classes: \n", get_class_distribution(letters_dataset))

# %%
plt.figure(figsize=(15,8))
sns.barplot(data = pd.DataFrame.from_dict([get_class_distribution(letters_dataset)]).melt(),
            x = "variable", y="value", hue="variable").set_title('Letters Class Distribution')

# %% [markdown]
# Random split

# %%
train_dataset, val_dataset = random_split(letters_dataset, (8000, 2355))

train_loader = DataLoader(dataset=train_dataset, shuffle=True, batch_size=32)
val_loader = DataLoader(dataset=val_dataset, shuffle=False, batch_size=32)
print("Length of the train_loader:", len(train_loader))
print("Length of the val_loader:", len(val_loader))
# Out:
# Length of the train_loader: 250
# Length of the val_loader: 74

# %%
''' Vizualize Images from dataloader '''

dataiter = iter(train_loader)
images, labels = dataiter.next()
print(type(images))
print(images.shape)
print(labels.shape)
image = np.transpose(images[0].numpy(), (1, 2, 0))
image = image.reshape(100,100)
print(set(image.flatten()))
plt.imshow(image, cmap='gray')
# Out:
# <class 'torch.Tensor'>
# torch.Size([32, 1, 100, 100])
# torch.Size([32])
# {0.0, 0.007843138, 0.99215686, 0.003921569, 0.011764706, 1.0, 0.99607843, 0.98039216, 0.9882353, 0.9843137, 0.019607844, 0.015686275, 0.972549, 0.9764706, 0.02745098, 0.023529412}

# %% [markdown]
# Model

# %%
device = torch.device("cuda" if torch.cuda.is_available() 
                                  else "cpu")
print(device)
# Out:
# cuda

# %% [markdown]
# ##Training

# %%
class CustomNet(nn.Module):
    def __init__(self):
        super(CustomNet, self).__init__()
        self.cnn_model = nn.Sequential(
            nn.Conv2d(1, 4, kernel_size = 3),
            nn.ReLU(),
            nn.AvgPool2d(2, stride = 2),
            nn.BatchNorm2d(4),
            nn.Conv2d(4, 8, kernel_size = 3),
            nn.ReLU(),
            nn.AvgPool2d(2, stride = 2),
            nn.BatchNorm2d(8),
            nn.Conv2d(8,16,kernel_size = 3),
            nn.ReLU(),
            nn.AvgPool2d(2, stride = 2),
            nn.BatchNorm2d(16),
            nn.Conv2d(16,32,kernel_size = 3),
            nn.ReLU())

        self.fc_model = nn.Sequential(
            nn.Linear(2048, 512), # (N, 2592) -> (N, 512)
            nn.BatchNorm1d(512),
            nn.ReLU(),
            nn.Linear(512, 30))  # (N, 512)  -> (N, 30)) #30 classes

    def forward(self, x):
        # print(x.shape)
        x = self.cnn_model(x)
        # print(x.shape) 
        x = x.view(x.size(0), -1)
        # print(x.shape)    
        x = self.fc_model(x)
        # print(x.shape)
        return x

# %%
model = CustomNet().to(device)
loss_fn = nn.CrossEntropyLoss()
opt = optim.Adam(model.parameters(), lr=0.001)

# %%
summary(model, (1, 100, 100))
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1            [-1, 4, 98, 98]              40
#               ReLU-2            [-1, 4, 98, 98]               0
#          AvgPool2d-3            [-1, 4, 49, 49]               0
#        BatchNorm2d-4            [-1, 4, 49, 49]               8
#             Conv2d-5            [-1, 8, 47, 47]             296
#               ReLU-6            [-1, 8, 47, 47]               0
#          AvgPool2d-7            [-1, 8, 23, 23]               0
#        BatchNorm2d-8            [-1, 8, 23, 23]              16
#             Conv2d-9           [-1, 16, 21, 21]           1,168
#              ReLU-10           [-1, 16, 21, 21]               0
#         AvgPool2d-11           [-1, 16, 10, 10]               0
#       BatchNorm2d-12           [-1, 16, 10, 10]              32
#            Conv2d-13             [-1, 32, 8, 8]           4,640
#              ReLU-14             [-1, 32, 8, 8]               0
#            Linear-15                  [-1, 512]       1,049,088
#       BatchNorm1d-16                  [-1, 512]           1,024
#              ReLU-17                  [-1, 512]               0
#            Linear-18                   [-1, 30]          15,390
# ================================================================
# Total params: 1,071,702
# Trainable params: 1,071,702
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.04
# Forward/backward pass size (MB): 1.24
# Params size (MB): 4.09
# Estimated Total Size (MB): 5.37
# ----------------------------------------------------------------

# %%
# Find total parameters and trainable parameters
total_params = sum(p.numel() for p in model.parameters())
print(f'{total_params:,} total parameters.')
total_trainable_params = sum(p.numel() for p in model.parameters() if p.requires_grad)
print(f'{total_trainable_params:,} training parameters.')
# Out:
# 1,071,702 total parameters.
# 1,071,702 training parameters.

# %%
def evaluation(dataloader):
    total, correct = 0, 0
    #keeping the network in evaluation mode 
    model.eval()
    for data in dataloader:
        inputs, labels = data
        #moving the inputs and labels to gpu
        inputs, labels = inputs.to(device), labels.to(device)
        outputs = model(inputs)
        _, pred = torch.max(outputs.data, 1)
        total += labels.size(0)
        correct += (pred == labels).sum().item()
    return 100 * correct / total

# %%
iter = []
loss_arr = []
loss_epoch_arr = []
max_epochs = 10 #epoch count

for epoch in range(max_epochs):

    for i, data in enumerate(train_loader, 0):

        inputs, labels = data
        # print(labels)
        inputs, labels = inputs.to(device), labels.to(device)
        # print()
        #forward pass
        outputs = model(inputs)
        # print('a')
        loss = loss_fn(outputs, labels)
        
        #backward and optimize
        opt.zero_grad()
        loss.backward()
        opt.step()

        if (i+1)%50 ==0:
            iter.append(i)
            loss_arr.append(loss.item())
            print('Epoch: %d/%d, Iterations: %d/%d, Loss: %0.4f, Test acc: %0.2f, Train acc: %0.2f' % (epoch+1, max_epochs, i+1, len(train_loader), loss.data, evaluation(val_loader), evaluation(train_loader)))
    loss_epoch_arr.append(loss.item())
        
    # print('Epoch: %d/%d, Test acc: %0.2f, Train acc: %0.2f' % (epoch, max_epochs, evaluation(val_loader), evaluation(train_loader)))
# Out:
# Epoch: 1/10, Iterations: 50/250, Loss: 0.1546, Test acc: 81.27, Train acc: 81.38
# Epoch: 1/10, Iterations: 100/250, Loss: 0.2758, Test acc: 94.10, Train acc: 95.10
# Epoch: 1/10, Iterations: 150/250, Loss: 0.0098, Test acc: 96.01, Train acc: 97.33
# Epoch: 1/10, Iterations: 200/250, Loss: 0.0474, Test acc: 96.99, Train acc: 97.86
# Epoch: 1/10, Iterations: 250/250, Loss: 0.2271, Test acc: 96.14, Train acc: 97.60
# Epoch: 2/10, Iterations: 50/250, Loss: 0.0079, Test acc: 96.56, Train acc: 97.83
# Epoch: 2/10, Iterations: 100/250, Loss: 0.0037, Test acc: 97.58, Train acc: 98.97
# Epoch: 2/10, Iterations: 150/250, Loss: 0.0143, Test acc: 97.75, Train acc: 99.16
# Epoch: 2/10, Iterations: 200/250, Loss: 0.0751, Test acc: 97.79, Train acc: 99.33
# Epoch: 2/10, Iterations: 250/250, Loss: 0.0418, Test acc: 97.37, Train acc: 98.74
# Epoch: 3/10, Iterations: 50/250, Loss: 0.0017, Test acc: 97.92, Train acc: 99.47
# Epoch: 3/10, Iterations: 100/250, Loss: 0.0012, Test acc: 97.49, Train acc: 99.38
# Epoch: 3/10, Iterations: 150/250, Loss: 0.0084, Test acc: 97.66, Train acc: 99.36
# Epoch: 3/10, Iterations: 200/250, Loss: 0.0049, Test acc: 97.71, Train acc: 99.39
# Epoch: 3/10, Iterations: 250/250, Loss: 0.0050, Test acc: 97.66, Train acc: 99.38
# Epoch: 4/10, Iterations: 50/250, Loss: 0.0055, Test acc: 97.75, Train acc: 99.71
# Epoch: 4/10, Iterations: 100/250, Loss: 0.0631, Test acc: 97.24, Train acc: 99.22
# Epoch: 4/10, Iterations: 150/250, Loss: 0.0076, Test acc: 98.39, Train acc: 99.72
# Epoch: 4/10, Iterations: 200/250, Loss: 0.0006, Test acc: 98.05, Train acc: 99.84
# Epoch: 4/10, Iterations: 250/250, Loss: 0.0265, Test acc: 98.05, Train acc: 99.62
# Epoch: 5/10, Iterations: 50/250, Loss: 0.0021, Test acc: 98.13, Train acc: 99.66
# Epoch: 5/10, Iterations: 100/250, Loss: 0.0022, Test acc: 97.92, Train acc: 99.66
# Epoch: 5/10, Iterations: 150/250, Loss: 0.0020, Test acc: 98.34, Train acc: 99.89
# Epoch: 5/10, Iterations: 200/250, Loss: 0.0006, Test acc: 97.96, Train acc: 99.69
# Epoch: 5/10, Iterations: 250/250, Loss: 0.0035, Test acc: 97.58, Train acc: 99.71
# Epoch: 6/10, Iterations: 50/250, Loss: 0.0035, Test acc: 96.90, Train acc: 98.78
# Epoch: 6/10, Iterations: 100/250, Loss: 0.0144, Test acc: 97.58, Train acc: 99.26
# Epoch: 6/10, Iterations: 150/250, Loss: 0.0072, Test acc: 97.96, Train acc: 99.84
# Epoch: 6/10, Iterations: 200/250, Loss: 0.0005, Test acc: 98.17, Train acc: 99.84
# Epoch: 6/10, Iterations: 250/250, Loss: 0.2318, Test acc: 97.03, Train acc: 99.19
# Epoch: 7/10, Iterations: 50/250, Loss: 0.0032, Test acc: 97.15, Train acc: 99.22
# Epoch: 7/10, Iterations: 100/250, Loss: 0.3303, Test acc: 97.88, Train acc: 99.66
# Epoch: 7/10, Iterations: 150/250, Loss: 0.0067, Test acc: 98.09, Train acc: 99.78
# Epoch: 7/10, Iterations: 200/250, Loss: 0.0004, Test acc: 98.13, Train acc: 99.81
# Epoch: 7/10, Iterations: 250/250, Loss: 0.0075, Test acc: 97.37, Train acc: 99.14
# Epoch: 8/10, Iterations: 50/250, Loss: 0.0008, Test acc: 97.79, Train acc: 99.58
# Epoch: 8/10, Iterations: 100/250, Loss: 0.0028, Test acc: 97.11, Train acc: 99.20
# Epoch: 8/10, Iterations: 150/250, Loss: 0.0129, Test acc: 97.62, Train acc: 99.51
# Epoch: 8/10, Iterations: 200/250, Loss: 0.0018, Test acc: 97.20, Train acc: 99.28
# Epoch: 8/10, Iterations: 250/250, Loss: 0.0016, Test acc: 97.24, Train acc: 99.05
# Epoch: 9/10, Iterations: 50/250, Loss: 0.1147, Test acc: 98.26, Train acc: 99.92
# Epoch: 9/10, Iterations: 100/250, Loss: 0.0177, Test acc: 97.66, Train acc: 99.38
# Epoch: 9/10, Iterations: 150/250, Loss: 0.0005, Test acc: 98.30, Train acc: 99.86
# Epoch: 9/10, Iterations: 200/250, Loss: 0.0000, Test acc: 98.39, Train acc: 99.99
# Epoch: 9/10, Iterations: 250/250, Loss: 0.0095, Test acc: 98.39, Train acc: 99.99
# Epoch: 10/10, Iterations: 50/250, Loss: 0.0201, Test acc: 98.39, Train acc: 99.95
# Epoch: 10/10, Iterations: 100/250, Loss: 0.0000, Test acc: 98.43, Train acc: 99.94
# Epoch: 10/10, Iterations: 150/250, Loss: 0.0434, Test acc: 98.47, Train acc: 99.94
# Epoch: 10/10, Iterations: 200/250, Loss: 0.0003, Test acc: 98.34, Train acc: 99.88
# Epoch: 10/10, Iterations: 250/250, Loss: 0.0000, Test acc: 98.47, Train acc: 99.95

# %%
plt.plot(loss_epoch_arr)
plt.show()

# %%
plt.plot(loss_arr)
plt.show()

# %%
model_path = '../models/pytorch/lenet7.pth'
torch.save(model.state_dict(), model_path)

# %%
full_model_path = '../models/pytorch/lenet7_full.pth'
torch.save(model, full_model_path)

# %% [markdown]
# ## Inference

# %%
from PIL import Image
img = Image.open('letters/A/7531.jpg')
# img = cv2.imread('letters/2/24.jpg',-1)
plt.imshow(img,cmap='gray')

# %%
img_t = image_transforms["train"](img)
batch_t = torch.unsqueeze(img_t, 0)

# %%
full_model_path = '../models/pytorch/lenet5_full.pth'
model = torch.load(full_model_path)
model.eval()
# Out:
# CustomNet(
#   (cnn_model): Sequential(
#     (0): Conv2d(1, 4, kernel_size=(5, 5), stride=(1, 1))
#     (1): ReLU()
#     (2): AvgPool2d(kernel_size=2, stride=2, padding=0)
#     (3): Conv2d(4, 8, kernel_size=(3, 3), stride=(1, 1))
#     (4): ReLU()
#     (5): AvgPool2d(kernel_size=2, stride=2, padding=0)
#     (6): Conv2d(8, 16, kernel_size=(3, 3), stride=(1, 1))
#     (7): ReLU()
#     (8): AvgPool2d(kernel_size=2, stride=2, padding=0)
#     (9): Conv2d(16, 32, kernel_size=(3, 3), stride=(1, 1))
#     (10): ReLU()
#     (11): AvgPool2d(kernel_size=2, stride=2, padding=0)
#   )
#   (fc_model): Sequential(
#     (0): Linear(in_features=512, out_features=256, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=256, out_features=30, bias=True)
#   )
# )

# %%
out = model(batch_t.to(device))
print(out.shape)
# Out:
# torch.Size([1, 30])

# %%
prediction = int(torch.max(out.cpu().data, 1)[1].numpy())
print(prediction)
# Out:
# 8

# %%
letter = idx2class[prediction]
print(letter)
# Out:
# A
